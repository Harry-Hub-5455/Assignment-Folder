# %% [markdown]
# #Assignment_5

# %% [markdown]
# ---

# %% [markdown]
# 1.What does an empty dictionary's code look like?
#
# 2.what is the value of dictionary value with key `'foo'` and the value `42` ?
#
# 3.What is the most significant distinction between a dictionary and a list?
#
# 4.What happens if you try to access spam `['foo'] if spam is {'bar':100}` ?
#
# 5.if a dictionary is stored in spam,what is the difference between the expressions `'cat'` in spam and `'cat'` in spam.keys() ?
#
# 6.if a dictionary is stored in spam,what is the difference between the expressions `'cat'` in spam and `'cat'` in spam.values() ?
#
# 7.what is a shortcut for the following code ?
#
# 8.How do you `'pretty print'` dictionary values using which modules and function ?

# %% [markdown]
# #Answer Sheet
#
# ---
#
#
#
# ---

# %% [markdown]
# 1.What does an empty dictionary's code look like?
#
# **Ans:**
#
# An empty dictionary is often represented by two empty curly brackets
# `d = {}` or `d = dict()`

# %% [markdown]
# ---

# %% [markdown]
# 2.what is the value of dictionary value with key 'foo' and the value 42 ?
#
# **Ans:**
#
# `{'foo':42}`

# %% [markdown]
# ---

# %% [markdown]
# 3.What is the most significant distinction between a dictionary and a list?
#
# **Ans:**
#
# Dictionaries are represented by `{}` where as listed are represented by `[]`
#
# The Items stored in a dictionary are Unordered , while the items in a list are ordered

# %% [markdown]
# ---

# %% [markdown]
# 4.What happens if you try to access spam ['foo'] if spam is {'bar':100} ?
#
# **Ans:**
#
# we will get a keyError `KeyError: 'foo'`

# %% [markdown]
# ---

# %% [markdown]
# 5.if a dictionary is stored in spam,what is the difference between the expressions `'cat'` in spam and `'cat'` in spam.keys() ?
#
# **Ans:**
#
# There is no difference . The operator checks whether a value exits as a key in the dictionary or not

# %% [markdown]
# ---

# %% [markdown]
# 6.if a dictionary is stored in spam,what is the difference between the expressions `'cat'` in spam and `'cat'` in spam.values() ?
#
# **Ans:**
#
# `'cat'` in spam checks whether there is a `'cat'` key in the dictionary, while `'cat'` in spam.values() checks whether there is a value `'cat'` for one of the keys in spam.

# %% [markdown]
# ---

# %% [markdown]
# 7.what is a shortcut for the following code ?
#
# `
# if 'color' not in spam:
# spam['color'] ='black'
# `
#
# **Ans:**
#
# `spam.setdefault('color','black')`

# %% [markdown]
# ---

# %% [markdown]
# 8.How do you 'pretty print' dictionary values using which modules and function ?
#
# **Ans:**
#
# we can pretty print a dictionary using three functions:
#
# 1. by using pprint() function of pprint module
#     * **Note:** pprint() function doesnot prettify nested dictionaries
# 2. by using dumps() method of json module
# 3. by using dumps() method of yaml module

# %%
nestdict = [
  {'Name': 'Harry', 'Age': '25', 'Residence': {'Country':'USA', 'City': 'New York'}},
  {'Name': 'Riya', 'Age': '21', 'Residence': {'Country':'INDIA', 'City': 'PUNE'}},
  {'Name': 'Annu', 'Age': '29', 'Residence': {'Country':'UK', 'City': 'England'}},
  {'Name': 'Ganesh', 'Age': '22', 'Residence': {'Country':'INDIA', 'City': 'MUMBAI'}}
]

print('Printing using print() function\n',nestdict)
print('-'*70)
import pprint
print('Printing using pprint() funciton')
pprint.pprint(nestdict)
print('-'*70)
import json
dump = json.dumps(nestdict, indent=4)
print('Printing using dumps() method\n', dump)
print('-'*70)
import yaml
dump = yaml.dump(nestdict)
print('Printing using dump() method\n', dump)
# Out:
# Printing using print() function
#  [{'Name': 'Harry', 'Age': '25', 'Residence': {'Country': 'USA', 'City': 'New York'}}, {'Name': 'Riya', 'Age': '21', 'Residence': {'Country': 'INDIA', 'City': 'PUNE'}}, {'Name': 'Annu', 'Age': '29', 'Residence': {'Country': 'UK', 'City': 'England'}}, {'Name': 'Ganesh', 'Age': '22', 'Residence': {'Country': 'INDIA', 'City': 'MUMBAI'}}]
# ----------------------------------------------------------------------
# Printing using pprint() funciton
# [{'Age': '25',
#   'Name': 'Harry',
#   'Residence': {'City': 'New York', 'Country': 'USA'}},
#  {'Age': '21',
#   'Name': 'Riya',
#   'Residence': {'City': 'PUNE', 'Country': 'INDIA'}},
#  {'Age': '29',
#   'Name': 'Annu',
#   'Residence': {'City': 'England', 'Country': 'UK'}},
#  {'Age': '22',
#   'Name': 'Ganesh',
#   'Residence': {'City': 'MUMBAI', 'Country': 'INDIA'}}]
# ----------------------------------------------------------------------
# Printing using dumps() method
#  [
#     {
#         "Name": "Harry",
#         "Age": "25",
#         "Residence": {
#             "Country": "USA",
#             "City": "New York"
#         }
#     },
#     {
#         "Name": "Riya",
#         "Age": "21",
#         "Residence": {
#             "Country": "INDIA",
#             "City": "PUNE"
#         }
#     },
#     {
#         "Name": "Annu",
#         "Age": "29",
#         "Residence": {
#             "Country": "UK",
#             "City": "England"
#         }
#     },
#     {
#         "Name": "Ganesh",
#         "Age": "22",
#         "Residence": {
#             "Country": "INDIA",
#             "City": "MUMBAI"
#         }
#     }
# ]
# ----------------------------------------------------------------------
# Printing using dump() method
#  - Age: '25'
#   Name: Harry
#   Residence:
#     City: New York
#     Country: USA
# - Age: '21'
#   Name: Riya
#   Residence:
#     City: PUNE
#     Country: INDIA
# - Age: '29'
#   Name: Annu
#   Residence:
#     City: England
#     Country: UK
# - Age: '22'
#   Name: Ganesh
#   Residence:
#     City: MUMBAI
#     Country: INDIA

# %% [markdown]
# ---

# %% [markdown]
# ---
#
#
#
# ---
